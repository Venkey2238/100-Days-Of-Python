# %%
print("Hello world")
x = "Hello"
print(x)
y = "Hello"
z = "world"
print(x+" "+z)
# Out:
# Hello world
# Hello
# Hello world

# %% [markdown]
# ![picture](https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200204160843/strings.jpg)

# %% [markdown]
# ## Reverse of a String

# %%
g = "geeksforgeeks"
print(g[::-1])
print(g[1:])
print("".join(reversed(g)))
# Out:
# skeegrofskeeg
# eeksforgeeks
# skeegrofskeeg

# %% [markdown]
# ## String Slicing

# %%
str = "geeksforgeeks"
print(str[3:6])
# Out:
# ksf

# %% [markdown]
# For the above code it only prints the words with index of 3,4,5 for [3:5] where lasr index is ignored

# %% [markdown]
# ### Deletion and Updation of String

# %%
str1 = "Hello"
str1[1] = 'p'
print(str1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e5c21b7c0509> in <module>
#       1 str1 = "Hello"
# ----> 2 str1[1] = 'p'
#       3 print(str1)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# so from the above code we understand that the updation of the string character is not posible
# But we can update the entire string

# %%
str1 = "hello"
print(str1)
str1 = "world"
print(str1)
# Out:
# hello
# world

# %% [markdown]
# For the Delection we cannot remove any of the  character from the string but with string slicing we can do it as shown below

# %%
str1 = "Hello"
str2 = str1[0:1] + str1[2:]
print(str2)
# Out:
# Hllo

# %% [markdown]
# ##Escape Sequencing in python

# %%
str = "hello "d" respect"
print(str)
# Out:
#   File "<ipython-input-10-3f317f40747f>", line 1
#     str = "hello "d" respect"
#                   ^
# SyntaxError: invalid syntax

# %%
str = 'hello "d\" respect'
str = "he'l a \"Gek\""
print(str)
# Out:
# he'l a "Gek"

# %% [markdown]
# like the above you can print quotes inside the quotes that all it all about

# %%
print("c:\\dell\\folrder")
# Out:
# c:\dell\folrder

# %%
String1 = "\110\145\154\154\157"
print(String1)
# Out:
# Hello

# %%
String1 = r"\110\145\154\154\157"
print(String1)
# Out:
# \110\145\154\154\157

# %%
str1 = ''
str2 = 'geeks'
 
# repr is used to print the string along with the quotes
 
# Returns str1
print(repr(str1 and str2)) 
 
# Returns str1  
print(repr(str2 and str1))
 
# Returns str2    
print(repr(str1 or str2))  
 
# Returns str2  
print(repr(str2 or str1))      
 
str1 = 'for'
 
# Returns str2
print(repr(str1 and str2)) 
 
# Returns str1  
print(repr(str2 and str1))
 
# Returns str1    
print(repr(str1 or str2)) 
 
# Returns str2    
print(repr(str2 or str1))      
 
str1='geeks'
 
# Returns False
print(repr(not str1))         
 
str1 = ''
 
# Returns True
print(repr(not str1))         
 

print(False and False)
# Out:
# ''
# ''
# 'geeks'
# 'geeks'
# 'geeks'
# 'for'
# 'for'
# 'geeks'
# False
# True
# False

# %% [markdown]
# ### For the and operation  if True then True else False

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %% [markdown]
# ## String template in python

# %%
from string import Template
t = Template("x is $x")
print(t.substitute({"x":1}))
# Out:
# x is 1

# %%
from string import Template
t = Template("my age is $age")
print(t.substitute({"age" : 23}))
# Out:
# my age is 23

# %%
from string import Template 
Student = [1,2,3,4]
t = Template("my seraial number is : $s")
for i in Student:
  print(t.substitute({"s": i}))
  i += 1
# Out:
# my seraial number is : 1
# my seraial number is : 2
# my seraial number is : 3
# my seraial number is : 4

# %% [markdown]
# ###if you need the $ in the code then follow as shown below

# %%
template = Template("$$ is the symbol for $name")
string = template.substitute(name="Dollar")
print(string)
# Out:
# $ is the symbol for Dollar

# %%
template = Template("The $noun looks ${noun}y")
string = template.substitute(noun = "fish")
print(string)
# Out:
# The fish looks fishy

# %% [markdown]
# ## Spliting a  string

# %%
str1 = "Hello,world"
x = str1.split(",")
print(x)
# Out:
# ['Hello', 'world']

# %%
str1 = "Hello"
print(len(str1))
l = []
for i in range(len(str1)):
  l.append(str1[i])
print(l)

t = "".join([i for i in l])
print(t)
# Out:
# 5
# ['H', 'e', 'l', 'l', 'o']
# Hello

# %%
l
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %% [markdown]
# ## above you can see a list of the individual strings you can combine them in a single string like shown be low with "".join() method

# %%
r = "".join([i for i in l])
print(r)
# Out:
# Hello

# %% [markdown]
# #Python Docstrings

# %%
def my_function():
    '''Demonstrates triple double quotes
    docstrings and does nothing really.'''
   
    return None
  
print("Using __doc__:")
print(my_function.__doc__)
  
print("Using help:")
help(my_function)

# %%
def fun():
  ''' hello my friend'''
  return True
print(fun.__doc__)

# %%
class ComplexNumber:
    """
    This is a class for mathematical operations on complex numbers.
      
    Attributes:
        real (int): The real part of complex number.
        imag (int): The imaginary part of complex number.
    """
  
    def __init__(self, real, imag):
        """
        The constructor for ComplexNumber class.
  
        Parameters:
           real (int): The real part of complex number.
           imag (int): The imaginary part of complex number.   
        """
  
    def add(self, num):
        """
        The function to add two Complex Numbers.
  
        Parameters:
            num (ComplexNumber): The complex number to be added.
          
        Returns:
            ComplexNumber: A complex number which contains the sum.
        """
  
        re = self.real + num.real
        im = self.imag + num.imag
  
        return ComplexNumber(re, im)
  
help(ComplexNumber)  # to access Class docstring
help(ComplexNumber.add)  # to access method's docstring

# %% [markdown]
# ###The difference between Python comments and docstrings
#
# You all must have got an idea about Python docstrings but have you ever wondered what is the difference between Python comments and docstrings. Let’s have a look at them.
#
# Python Comments are the useful information that the developers provide to make the reader understand the source code. It explains the logic or a part of it used in the code. It is written by using # symbol
# Whereas Python Docstrings as mentioned above provides a convenient way of associating documentation with Python modules, functions, classes, and methods.

# %%
x = "GeeksforGeeks"
y = "ter"
if y in x :
  print("exsist")
else :
  print("not exsists")





"""def hell(input,pattern):
  if len(input)==0 and len(pattern)==0:
    return 'true'
  if len(pattern)==0:
    return 'true'
  while(len(input)!=0):
    index = input.find(pattern)
    if (index ==(-1)):
      return 'false'
    input = input[0:index] + input[index + len(pattern):]
  return 'true'
if __name__ == "__main__":
  input = "GeeksforGeeks"
  pattern = "Geeks"
  print(hell(input,pattern))"""

# %% [markdown]
# #Counter method is used to tell the character frequencies in a word as show
# below is a code which returns the duplicate elements

# %%
from collections import Counter
 
 
def find_dup_char(input):
 
    # now create dictionary using counter method
    # which will have strings as key and their
    # frequencies as value
    WC = Counter(input)
    print(WC)
 
    # Finding no. of  occurrence of a character
    # and get the index of it.
    for letter, count in WC.items():
        if (count > 1):
            print(letter)
 
 
# Driver program
if __name__ == "__main__":
    input = 'geeksforgeeks'
    find_dup_char(input)

# %% [markdown]
# ##finding the duplicate strings

# %%
def find_e(input):
  x = []
  for i in input:
    if i not in x and input.count(i)>1:
      x.append(i)
  print("".join(x))
if __name__=="__main__":
  input = "geeksforgeeks"
  find_e(input)

# %% [markdown]
# # Reverse a string in python without slicing

# %%
str1 = "Hello"
x  = [i for i in str1]
print(x)
for i in reversed(range(len(x))):
  print("".join(x[i]),end="")
# Out:
# ['H', 'e', 'l', 'l', 'o']
# olleH

# %%
str1 = "hello"
for i in range(len(str1)-1, - 1,-1):
   print(str1[i],end="")

# %% [markdown]
# ##range function

# %%
for i in range(5):
  print(i)
print("------------")
for i in range(0,5):
  print(i)
print("------------")
for i in range(0,5,2):
  print(i)
print("------------")
for i in range(5,-1,-1):   ## this line will tell us that to start at 5 and stop at -1 and go on subracting one 
  print(i)

# %% [markdown]
# ## Check the given string is palindrome or not

# %%
str1 = "malayal"
x = [i for i in str1]
z = len(x)
print(z)
y = []
for i in reversed(range(z)):
  y.append(x[i])
if x == y:
  print("its a palindrome")
else:
  print("not a palindrome")

# %%
str2 = "tomo"
if (str2 == str2[::-1]):
  print("it is a palindrome")
else:
  print("not a palindrome")

# %% [markdown]
# comparing the first and last string

# %%
str1 = "tomot"
str2 = ""
for i in range(0,int(len(str1)/2)):
  if (str1[i] == str1[len(str1)-i-1]):

# %%
str1 = "T"
str2 = ""
for i in str1:
  str2 = i + str2
if (str1 == str2):
  print("yes")
else:
  print("no")

# %%
str  =  "HeLLo"
x = str.swapcase()
print(x)

# %%
str = "Hello My Friend Hello Hello"
x = str.replace("Hello","hello",3)
print(x)

# %% [markdown]
# ## The tile letters are the letter where the starting letters are capital and others are small
# -> Ex: Hello is titled
# -> Ex: Geeks is titled
# -> Ex: hello is not titled

# %%
str = "Hello"
x = str.istitle()
print(x)
str2 = "helloH"
y = str2.istitle()
print(y)

# %%
str = "hello for world"
x = str.partition("for")
print(x)
print(type(x))

# %% [markdown]
# ##Q) locate a Highest sub-string location in a string
#
# ---

# %%
srt = "Hello world how Hello are you Hello"
x = srt.rindex("Hello")
print(x)

# %%
## Checking a substring at a given range
str = "Hello World Hello"
x = str.rindex("Hello",0,6)
print(x)

# %% [markdown]
# ##Alphabetically highest character

# %%
str = "geeks"
print(max(str))

# %% [markdown]
# ##Alphabetically lowest character

# %%
str = "geeks"
print(min(str))

# %% [markdown]
# ##splitline() method

# %%
str = "Hello World"
x = str.splitlines(2)
print(x)

# %%
str = "Hello c and r for free"
x  = str.find("Hello")
print(x)
